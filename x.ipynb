# %%
import os
import requests

API_URL = "https://router.huggingface.co/featherless-ai/v1/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

output = query({
    "inputs": "Tell me about Egypt Demographics",
})

# %%
output
# Out:
# {'error': 'Model not supported by provider featherless-ai'}

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="meta-llama/Llama-3.1-8B-Instruct:auto",
    messages=[
        {
            "role": "user",
            "content": "Tell me about Egypt Demographics"
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# Cell In[8], line 8
#       2 from huggingface_hub import InferenceClient
#       4 client = InferenceClient(
#       5     api_key=os.environ["HF_TOKEN"],
#       6 )
# ----> 8 completion = client.chat.completions.create(
#       9     model="meta-llama/Llama-3.1-8B-Instruct:auto",
#      10     messages=[
#      11         {
#      12             "role": "user",
#      13             "content": "Tell me about Egypt Demographics"
#      14         }
#      15     ],
#      16 )
#      18 print(completion.choices[0].message)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\inference\_client.py:886, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     883 payload_model = model or self.model
#     885 # Get the provider helper
# --> 886 provider_helper = get_provider_helper(
#     887     self.provider,
#     888     task="conversational",
#     889     model=model_id_or_url
#     890     if model_id_or_url is not None and model_id_or_url.startswith(("http://", "https://"))
#     891     else payload_model,
#     892 )
#     894 # Prepare the payload
#     895 parameters = {
#     896     "model": payload_model,
#     897     "frequency_penalty": frequency_penalty,
#    (...)
#     914     **(extra_body or {}),
#     915 }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\inference\_providers\__init__.py:195, in get_provider_helper(provider, task, model)
#     193     if model is None:
#     194         raise ValueError("Specifying a model is required when provider is 'auto'")
# --> 195     provider_mapping = _fetch_inference_provider_mapping(model)
#     196     provider = next(iter(provider_mapping)).provider
#     198 provider_tasks = PROVIDERS.get(provider)  # type: ignore
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\inference\_providers\_common.py:280, in _fetch_inference_provider_mapping(model)
#     275 """
#     276 Fetch provider mappings for a model from the Hub.
#     277 """
#     278 from huggingface_hub.hf_api import HfApi
# --> 280 info = HfApi().model_info(model, expand=["inferenceProviderMapping"])
#     281 provider_mapping = info.inference_provider_mapping
#     282 if provider_mapping is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\utils\_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\utils\_validators.py:160, in validate_repo_id(repo_id)
#     154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
# --> 160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#     162         " forbidden, '-' and '.' cannot start or end the name, max length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#     166 if "--" in repo_id or ".." in repo_id:
#     167     raise HFValidationError(f"Cannot have -- or .. in repo_id: '{repo_id}'.")
#
# HFValidationError: Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are forbidden, '-' and '.' cannot start or end the name, max length is 96: 'meta-llama/Llama-3.1-8B-Instruct:auto'.

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "meta-llama/Llama-3.1-8B-Instruct:fastest"
})

print(response["choices"][0]["message"])
# Out:
# {'content': 'The capital of France is Paris.', 'role': 'assistant'}
